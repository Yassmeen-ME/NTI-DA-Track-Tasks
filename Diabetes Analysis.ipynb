# %%
#install Libraries
# %pip install pandas
# %pip install numpy 
# %pip install matplotlib
# %pip install seaborn

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#import dataset
df_diabetes= pd.read_csv("D:/Yassmeen/NTI-Data Analysis/S6 Matplotlib & Seaborn/Task 6/diabetes.csv")

# %%
#overview
df_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               769 non-null    int64
#  1   Glucose                   769 non-null    int64
#  2   BloodPressure             769 non-null    int64
#  3   SkinThickness             769 non-null    int64
#  4   Insulin                   769 non-null    int64
#  5   BMI                       769 non-null    float64
#  6   DiabetesPedigreeFunction  769 non-null    float64
#  7   Age                       769 non-null    int64
#  8   Outcome                   769 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.2 KB

# %%
#overview
df_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
# 768            0      123             77              0        1  36.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#overview
df_diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   769.000000  769.000000     769.000000     769.000000  769.000000
# mean      3.840052  120.897269      69.115735      20.509753   79.697009
# std       3.370237   31.951886      19.345296      15.959020  115.203999
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   29.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                769.000000  769.000000  769.000000
# mean    31.998179                  0.471590   33.269181    0.349805
# std      7.880557                  0.331208   11.778737    0.477219
# ...

# %%
#check duplicates
df_diabetes.duplicated().sum()
# Out:
# 0

# %%
#No. of Diabetic vs Not Diabetic (count of Outcome)
df_diabetes['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    269
# Name: count, dtype: int64

# %%
#No of pregnancies
df_diabetes['Pregnancies'].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     112
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: count, dtype: int64

# %%
#No of pregnancies based on outcome
df_diabetes.groupby('Outcome')['Pregnancies'].value_counts()
# Out:
# Outcome  Pregnancies
# 0        1              106
#          2               84
#          0               73
#          3               48
#          4               45
#          5               36
#          6               34
#          7               20
#          8               16
#          10              14
#          9               10
#          12               5
#          13               5
#          11               4
# 1        0               39
#          1               29
#          3               27
#          7               25
#          4               23
#          8               22
#          5               21
#          2               19
#          9               18
#          6               16
#          10              10
#          11               7
#          13               5
#          12               4
#          14               2
#          15               1
#          17               1
# Name: count, dtype: int64

# %%
#what's the correlation between no. of pregrancies and being diabetic
df_diabetes['Pregnancies'].corr(df_diabetes['Outcome'])  
#negative correlation
# Out:
# 0.21941783948103305

# %%
#correlation (using heatmap)
#df_diabetes.corr()
plt.title('Correlation Heatmap')
sns.heatmap(data=df_diabetes.corr(), annot=True)
plt.show()

# %%
#No. of Diabetic vs Not Diabetic (count of Outcome)
plt.title('No of Healthy vs Diabetic')
plt.pie(df_diabetes['Outcome'].value_counts(), explode=(0, 0.05), shadow=True, labels=['Healthy','Diabetic'], autopct='%1.2f%%', startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x22dc5c66720>,
# ...
#  [Text(0.4999900713196203, -0.979800963758355, 'Healthy'),
#   Text(-0.5227168927432402, 1.0243373712019161, 'Diabetic')],
#  [Text(0.2727218570834292, -0.534436889322739, '65.02%'),
#   Text(-0.29544867850704876, 0.5789732967663004, '34.98%')])

# %%
#Age Distribution
df_diabetes.Age.plot(kind='hist')
plt.title('Age Distribution')
plt.show()

# %%
#Relation between Age & Glucose based on outcome
sns.scatterplot(data=df_diabetes, x='Age' , y='Glucose', hue='Outcome')
plt.title('Relation between Age & Glucose based on Outcome')
plt.show()

# %%
#Relation between Age & BMI based on outcome
sns.scatterplot(data=df_diabetes, x='Age' , y='BMI', hue='Outcome')
plt.title('Relation between Age & BMI based on Outcome')
plt.show()

# %%
#FEATURES dISTRIBUTION
df_diabetes.hist(figsize=(14,8))
plt.suptitle('Features Distribution')
plt.show()

# %%
#Relation between Pregnancies & Outcome
PO_relation= df_diabetes.groupby('Outcome')['Pregnancies'].mean().reset_index()
sns.barplot(data=PO_relation,x='Outcome', y='Pregnancies')
plt.title('Average Pregnancies by Diabetes Outcome')
plt.show()

# %%
#relation between blood pressure & Outcome
sns.scatterplot(data=df_diabetes, y='Outcome', x='BloodPressure')
plt.title('Relation between Blood Pressure & Outcome')
plt.show()

# %%
#Average of Age based on Oucome
plt.title('Average of Age based on Oucome')
df_diabetes_filtered = df_diabetes.groupby('Outcome')['Age'].mean().reset_index()
sns.barplot(y=df_diabetes_filtered['Age'], x=df_diabetes_filtered['Outcome'])
plt.show()
